# %%
import pandas as pd

# %%
# !ls test_org
# Out:
# test.txt

# %%
df = pd.read_csv("./test_org/test.txt",delimiter=" ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2a7bd73a4b90> in <module>
# ----> 1 df = pd.read_csv("./test_org/test.txt",header = False,delimiter=" ")
#
# ~/.virtualenvs/analysis/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
df
# Out:
#      thumb0032.jpg  0.0721484  0.00672829  -0.00634376  0.999808  0.00550985  \
# 0    thumb0418.jpg   0.671782   -0.123293     1.249510 -0.162853    0.056265
# 1    thumb0227.jpg   1.437030   -0.057103     3.974700 -0.161480    0.060273
# 2    thumb0510.jpg   0.340231   -0.110829     1.250140 -0.039475    0.040625
# 3    thumb0297.jpg  -0.459124   -0.077722     1.797410  0.178827    0.026290
# 4    thumb0107.jpg   0.374735    0.073912    -2.014110  0.993904   -0.011525
# ..             ...        ...         ...          ...       ...         ...
# 158  thumb0851.jpg   0.228958   -0.471228     4.654060  0.999782    0.008942
# 159  thumb0783.jpg   3.460680    1.242800     5.640740  0.961551   -0.126256
# 160  thumb0933.jpg   0.176581   -0.210839     2.225840  0.999600    0.003188
# 161  thumb0332.jpg   1.038720   -0.134877     1.242610 -0.278410    0.029449
# 162  thumb0046.jpg   0.065987    0.026399    -0.342621  0.999652    0.002770
#
#      -0.0186638  -0.00244931
# ...
